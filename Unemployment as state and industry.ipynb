# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading and editing the table for state codes

# %%
cite = 'https://download.bls.gov/pub/time.series/nc/nc.state'

states_df =  pd.read_csv(cite , sep = '\t')

state_code = np.array(states_df.index[1:46])
state_name = np.array(states_df.state_code[1:46])

states_df_edit = pd.DataFrame(columns = ['state_code', 'state_name'] )

states_df_edit.state_code = state_code
states_df_edit.state_name = state_name

code_append = np.array([16, 35, 46, 49, 50, 56  ])
name_append = np.array(['Idaho', 'New Mexico', 'South Dakota', 'Utah', 'Vermont', 'Wyoming'])

states_append =  pd.DataFrame(columns = ['state_code', 'state_name'] )
states_append.state_code = code_append
states_append.state_name = name_append
states_df_edit = states_df_edit.append(states_append, ignore_index=True)

states_df_edit = states_df_edit.sort_values( by=['state_name'] )
states_df = states_df_edit.reset_index( drop = True )
states_df
# Out:
#     state_code            state_name
# 0            1               Alabama
# 1            2                Alaska
# 2            4               Arizona
# 3            5              Arkansas
# 4            6            California
# 5            8              Colorado
# 6            9           Connecticut
# 7           10              Delaware
# 8           11  District of Columbia
# 9           12               Florida
# 10          13               Georgia
# 11          15                Hawaii
# 12          16                 Idaho
# 13          17              Illinois
# 14          18               Indiana
# 15          19                  Iowa
# 16          20                Kansas
# 17          21              Kentucky
# 18          22             Louisiana
# 19          23                 Maine
# 20          24              Maryland
# 21          25         Massachusetts
# 22          26              Michigan
# 23          27             Minnesota
# 24          28           Mississippi
# 25          29              Missouri
# 26          30               Montana
# 27          31              Nebraska
# 28          32                Nevada
# 29          33         New Hampshire
# 30          34            New Jersey
# 31          35            New Mexico
# 32          36              New York
# 33          37        North Carolina
# 34          38          North Dakota
# 35          39                  Ohio
# 36          40              Oklahoma
# 37          41                Oregon
# 38          42          Pennsylvania
# 39          44          Rhode Island
# 40          45        South Carolina
# 41          46          South Dakota
# 42          47             Tennessee
# 43          48                 Texas
# 44          49                  Utah
# 45          50               Vermont
# 46          51              Virginia
# 47          53            Washington
# 48          54         West Virginia
# 49          55             Wisconsin
# 50          56               Wyoming

# %% [markdown]
# ### reading in and editing the sector code

# %%
link = 'https://download.bls.gov/pub/time.series/ce/ce.supersector'

sector_df = pd.read_csv(link , sep = '\t')

# sector_df = sector_df.drop([5, 6, 8, 9, 14], axis = 0 )

code_append = np.array([15])
name_append = np.array(['Mining, Logging, and Construction'])

sector_append = pd.DataFrame(columns = ['supersector_code', 'supersector_name'] )
sector_append.supersector_code = code_append
sector_append.supersector_name = name_append


sector_df = sector_df.append(sector_append, ignore_index=True)
sector_df = sector_df.sort_values( by=['supersector_code'] )
sector_df = sector_df.reset_index(drop=True)
sector_df
# Out:
#     supersector_code                      supersector_name
# 0                  0                         Total nonfarm
# 1                  5                         Total private
# 2                  6                       Goods-producing
# 3                  7                     Service-providing
# 4                  8             Private service-providing
# 5                 10                    Mining and logging
# 6                 15     Mining, Logging, and Construction
# 7                 20                          Construction
# 8                 30                         Manufacturing
# 9                 31                         Durable Goods
# 10                32                      Nondurable Goods
# 11                40  Trade, transportation, and utilities
# 12                41                       Wholesale trade
# 13                42                          Retail trade
# 14                43        Transportation and warehousing
# 15                44                             Utilities
# 16                50                           Information
# 17                55                  Financial activities
# 18                60    Professional and business services
# 19                65         Education and health services
# 20                70               Leisure and hospitality
# 21                80                        Other services
# 22                90                            Government

# %% [markdown]
# ### Reading and editing the data type code

# %%
link = 'https://download.bls.gov/pub/time.series/ce/ce.datatype'
    
data_type_df = pd.read_csv(link , sep = '\t')

# %% [markdown]
# ### Extracting data
#
# Note: the table that we are interested in are formated like this:
# Link: https://www.bls.gov/help/hlpforma.htm
# 	             12345678901234567890
# 	Series ID    SMU19197802023800001
# 	Positions       Value           Field Name
# 	1-2             SM              Prefix
# 	3               U               Seasonal Adjustment Code
# 	4-5             19              State Code
# 	6-10            19780           Area Code
# 	11-18           20238000        SuperSector and Industry Code
# 	19-20           01             	Data Type Code

# %%
link = 'https://data.bls.gov/timeseries/SMS01000009000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true'
data_df = pd.read_html(link)
data_df = data_df[1]

cols = [month + str(' ') + str(year) for year in np.arange(2010, 2021, 1) for month in data_df.columns.values[1:-1]]

df_final = pd.DataFrame(columns = cols)

df_final['State'] = ''

df_final['Key_word'] = ''


cols = ['State', 'Key_word', 'Jan 2010', 'Feb 2010', 'Mar 2010', 'Apr 2010', 'May 2010',
       'Jun 2010', 'Jul 2010', 'Aug 2010', 'Sep 2010', 'Oct 2010',
       'Nov 2010', 'Dec 2010', 'Jan 2011', 'Feb 2011', 'Mar 2011',
       'Apr 2011', 'May 2011', 'Jun 2011', 'Jul 2011', 'Aug 2011',
       'Sep 2011', 'Oct 2011', 'Nov 2011', 'Dec 2011', 'Jan 2012',
       'Feb 2012', 'Mar 2012', 'Apr 2012', 'May 2012', 'Jun 2012',
       'Jul 2012', 'Aug 2012', 'Sep 2012', 'Oct 2012', 'Nov 2012',
       'Dec 2012', 'Jan 2013', 'Feb 2013', 'Mar 2013', 'Apr 2013',
       'May 2013', 'Jun 2013', 'Jul 2013', 'Aug 2013', 'Sep 2013',
       'Oct 2013', 'Nov 2013', 'Dec 2013', 'Jan 2014', 'Feb 2014',
       'Mar 2014', 'Apr 2014', 'May 2014', 'Jun 2014', 'Jul 2014',
       'Aug 2014', 'Sep 2014', 'Oct 2014', 'Nov 2014', 'Dec 2014',
       'Jan 2015', 'Feb 2015', 'Mar 2015', 'Apr 2015', 'May 2015',
       'Jun 2015', 'Jul 2015', 'Aug 2015', 'Sep 2015', 'Oct 2015',
       'Nov 2015', 'Dec 2015', 'Jan 2016', 'Feb 2016', 'Mar 2016',
       'Apr 2016', 'May 2016', 'Jun 2016', 'Jul 2016', 'Aug 2016',
       'Sep 2016', 'Oct 2016', 'Nov 2016', 'Dec 2016', 'Jan 2017',
       'Feb 2017', 'Mar 2017', 'Apr 2017', 'May 2017', 'Jun 2017',
       'Jul 2017', 'Aug 2017', 'Sep 2017', 'Oct 2017', 'Nov 2017',
       'Dec 2017', 'Jan 2018', 'Feb 2018', 'Mar 2018', 'Apr 2018',
       'May 2018', 'Jun 2018', 'Jul 2018', 'Aug 2018', 'Sep 2018',
       'Oct 2018', 'Nov 2018', 'Dec 2018', 'Jan 2019', 'Feb 2019',
       'Mar 2019', 'Apr 2019', 'May 2019', 'Jun 2019', 'Jul 2019',
       'Aug 2019', 'Sep 2019', 'Oct 2019', 'Nov 2019', 'Dec 2019',
       'Jan 2020', 'Feb 2020', 'Mar 2020', 'Apr 2020', 'May 2020',
       'Jun 2020', 'Jul 2020', 'Aug 2020', 'Sep 2020', 'Oct 2020', 
       'Nov 2020', 'Dec 2020']

df_final = df_final.reindex(columns = cols )

df_final
# Out:
# Empty DataFrame
# Columns: [State, Key_word, Jan 2010, Feb 2010, Mar 2010, Apr 2010, May 2010, Jun 2010, Jul 2010, Aug 2010, Sep 2010, Oct 2010, Nov 2010, Dec 2010, Jan 2011, Feb 2011, Mar 2011, Apr 2011, May 2011, Jun 2011, Jul 2011, Aug 2011, Sep 2011, Oct 2011, Nov 2011, Dec 2011, Jan 2012, Feb 2012, Mar 2012, Apr 2012, May 2012, Jun 2012, Jul 2012, Aug 2012, Sep 2012, Oct 2012, Nov 2012, Dec 2012, Jan 2013, Feb 2013, Mar 2013, Apr 2013, May 2013, Jun 2013, Jul 2013, Aug 2013, Sep 2013, Oct 2013, Nov 2013, Dec 2013, Jan 2014, Feb 2014, Mar 2014, Apr 2014, May 2014, Jun 2014, Jul 2014, Aug 2014, Sep 2014, Oct 2014, Nov 2014, Dec 2014, Jan 2015, Feb 2015, Mar 2015, Apr 2015, May 2015, Jun 2015, Jul 2015, Aug 2015, Sep 2015, Oct 2015, Nov 2015, Dec 2015, Jan 2016, Feb 2016, Mar 2016, Apr 2016, May 2016, Jun 2016, Jul 2016, Aug 2016, Sep 2016, Oct 2016, Nov 2016, Dec 2016, Jan 2017, Feb 2017, Mar 2017, Apr 2017, May 2017, Jun 2017, Jul 2017, Aug 2017, Sep 2017, Oct 2017, Nov 2017, Dec 2017, Jan 2018, Feb 2018, ...]
# Index: []
#
# [0 rows x 134 columns]

# %%
for idx, state in enumerate(states_df.state_code):
    for idx_sector, sector in enumerate(sector_df.supersector_code):
        print(states_df.state_name[idx], sector_df.supersector_name[idx_sector])
        
        html_path = 'https://data.bls.gov/timeseries/SMS' + str(state).zfill(2) + '00000' + str(sector).zfill(2) + '00000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true'
        print('link:', html_path)
        
        try:
            data_df = pd.read_html(html_path)
            data_df = data_df[1]
            data_df = data_df.rename(columns = {'Unnamed: 0': "year"})
            
            data_df = data_df.drop(['Unnamed: 13'], axis=1)
            data_df = data_df.drop([11], axis = 0 )
            
            new_row = [data_df[month][data_df.year == str(year)].item() for year in np.arange(2010, 2021, 1) for month in data_df.columns.values[1:]] 
            new_row.insert(0, states_df.state_name[idx]) 
            new_row.insert(1, sector_df.supersector_name[idx_sector]) 
            df_length = len(df_final)
            df_final.loc[df_length] = new_row
        except ValueError:
            pass

        print('')
# Out:
# Alabama Total nonfarm
# link: https://data.bls.gov/timeseries/SMS01000000000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# /Users/vaishaliparkash/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: `item` has been deprecated and will be removed in a future version
#   app.launch_new_instance()
# Alabama Total private
# link: https://data.bls.gov/timeseries/SMS01000000500000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Alabama Goods-producing
# link: https://data.bls.gov/timeseries/SMS01000000600000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Alabama Service-providing
# link: https://data.bls.gov/timeseries/SMS01000000700000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Alabama Private service-providing
# link: https://data.bls.gov/timeseries/SMS01000000800000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Alabama Mining and logging
# link: https://data.bls.gov/timeseries/SMS01000001000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Alabama Mining, Logging, and Construction
# link: https://data.bls.gov/timeseries/SMS01000001500000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Alabama Construction
# link: https://data.bls.gov/timeseries/SMS01000002000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Alabama Manufacturing
# link: https://data.bls.gov/timeseries/SMS01000003000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Alabama Durable Goods
# link: https://data.bls.gov/timeseries/SMS01000003100000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Alabama Nondurable Goods
# link: https://data.bls.gov/timeseries/SM
001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Mining and logging
# link: https://data.bls.gov/timeseries/SMS56000001000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Mining, Logging, and Construction
# link: https://data.bls.gov/timeseries/SMS56000001500000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Construction
# link: https://data.bls.gov/timeseries/SMS56000002000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Manufacturing
# link: https://data.bls.gov/timeseries/SMS56000003000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Durable Goods
# link: https://data.bls.gov/timeseries/SMS56000003100000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Nondurable Goods
# link: https://data.bls.gov/timeseries/SMS56000003200000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Trade, transportation, and utilities
# link: https://data.bls.gov/timeseries/SMS56000004000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Wholesale trade
# link: https://data.bls.gov/timeseries/SMS56000004100000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Retail trade
# link: https://data.bls.gov/timeseries/SMS56000004200000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Transportation and warehousing
# link: https://data.bls.gov/timeseries/SMS56000004300000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Utilities
# link: https://data.bls.gov/timeseries/SMS56000004400000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Information
# link: https://data.bls.gov/timeseries/SMS56000005000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Financial activities
# link: https://data.bls.gov/timeseries/SMS56000005500000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Professional and business services
# link: https://data.bls.gov/timeseries/SMS56000006000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Education and health services
# link: https://data.bls.gov/timeseries/SMS56000006500000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Leisure and hospitality
# link: https://data.bls.gov/timeseries/SMS56000007000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Other services
# link: https://data.bls.gov/timeseries/SMS56000008000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
#
# Wyoming Government
# link: https://data.bls.gov/timeseries/SMS56000009000000001?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true

# %%
df_final
# Out:
#         State                            Key_word Jan 2010 Feb 2010 Mar 2010  \
# 0     Alabama                       Total nonfarm   1881.7   1879.3   1883.1
# 1     Alabama                       Total private   1493.4   1491.1   1493.4
# 2     Alabama                     Goods-producing    336.4    335.2    335.9
# 3     Alabama                   Service-providing   1545.3   1544.1   1547.2
# 4     Alabama           Private service-providing   1157.0   1155.9   1157.5
# ...       ...                                 ...      ...      ...      ...
# 1102  Wyoming  Professional and business services     17.1     16.9     17.0
# 1103  Wyoming       Education and health services     26.0     26.1     26.1
# 1104  Wyoming             Leisure and hospitality     32.2     32.3     32.0
# 1105  Wyoming                      Other services     13.7     13.7     13.8
# 1106  Wyoming                          Government     70.9     71.1     71.7
#
#      Apr 2010 May 2010 Jun 2010 Jul 2010 Aug 2010  ... Mar 2020 Apr 2020  \
# 0      1886.3   1898.3   1896.5   1895.7   1891.5  ...   2076.6   1865.8
# 1      1495.3   1499.1   1501.7   1503.1   1501.5  ...   1681.0   1477.1
# 2       337.0    337.5    337.7    336.8    335.8  ...    377.2    347.5
# 3      1549.3   1560.8   1558.8   1558.9   1555.7  ...   1699.4   1518.3
# 4      1158.3   1161.6   1164.0   1166.3   1165.7  ...   1303.8   1129.6
# ...       ...      ...      ...      ...      ...  ...      ...      ...
# 1102     17.2     17.1     17.2     17.4     17.6  ...     18.3     17.4
# 1103     26.3     26.2     26.4     26.3     26.4  ...     29.1     26.6
# 1104     32.6     32.6     32.7     32.7     32.9  ...     36.1     24.1
# 1105     14.1     14.0     13.9     14.1     14.2  ...     16.1     13.6
# 1106     71.3     72.9     72.4     70.7     70.5  ...     68.5     66.8
#
#      May 2020   Jun 2020 Jul 2020 Aug 2020 Sep 2020 Oct 2020 Nov 2020 Dec 2020
# 0      1908.9  1954.2(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 1      1531.5  1582.5(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 2       356.1   361.6(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 3      1552.8  1592.6(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 4      1175.4  1220.9(P)      NaN      NaN      NaN      NaN      NaN      NaN
# ...       ...        ...      ...      ...      ...      ...      ...      ...
# 1102     17.7    17.6(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 1103     27.5    28.2(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 1104     26.6    28.0(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 1105     13.7    14.6(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 1106     64.7    65.7(P)      NaN      NaN      NaN      NaN      NaN      NaN
#
# [1107 rows x 134 columns]

# %%
mon_list = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
for idx, state in enumerate(states_df.state_code):
    print(states_df.state_name[idx], )
    print("")
    html_path = 'https://data.bls.gov/timeseries/LASST' + str(state).zfill(2) + '0000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true'
    print('link:', html_path)
              
    try:
        data_df = pd.read_html(html_path)
        data_df = data_df[1]


        data_df = data_df.rename(columns = {'Unnamed: 0': "year"})
        data_df = data_df.rename(columns = {'Unnamed: 1': "month"})
        cols = data_df.columns.values[2:]

        
        for column in cols:
            data = data_df[column][:-1]

            new_row = list( data.T )

            new_row.insert(0, states_df.state_name[idx]) 
            new_row.insert(1, column)
            new_row.extend(['NaN', 'NaN', 'NaN', 'NaN', 'NaN', 'NaN'])
            
            df_length = len(df_final)
            df_final.loc[df_length] = new_row
              
    except ValueError:
        pass
        print('')
# Out:
# Alabama
#
# link: https://data.bls.gov/timeseries/LASST010000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Alaska
#
# link: https://data.bls.gov/timeseries/LASST020000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Arizona
#
# link: https://data.bls.gov/timeseries/LASST040000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Arkansas
#
# link: https://data.bls.gov/timeseries/LASST050000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# California
#
# link: https://data.bls.gov/timeseries/LASST060000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Colorado
#
# link: https://data.bls.gov/timeseries/LASST080000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Connecticut
#
# link: https://data.bls.gov/timeseries/LASST090000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Delaware
#
# link: https://data.bls.gov/timeseries/LASST100000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# District of Columbia
#
# link: https://data.bls.gov/timeseries/LASST110000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Florida
#
# link: https://data.bls.gov/timeseries/LASST120000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Georgia
#
# link: https://data.bls.gov/timeseries/LASST130000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Hawaii
#
# link: https://data.bls.gov/timeseries/LASST150000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Idaho
#
# link: https://data.bls.gov/timeseries/LASST160000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Illinois
#
# link: https://data.bls.gov/timeseries/LASST170000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Indiana
#
# link: https://data.bls.gov/timeseries/LASST180000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Iowa
#
# link: https://data.bls.gov/timeseries/LASST190000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Kansas
#
# link: https://data.bls.gov/timeseries/LASST200000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Kentucky
#
# link: https://data.bls.gov/timeseries/LASST210000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Louisiana
#
# link: https://data.bls.gov/timeseries/LASST220000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Maine
#
# link: https://data.bls.gov/timeseries/LASST230000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Maryland
#
# link: https://data.bls.gov/timeseries/LASST240000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Massachusetts
#
# link: https://data.bls.gov/timeseries/LASST250000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Michigan
#
# link: https://data.bls.gov/timeseries/LASST260000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Minnesota
#
# link: https://data.bls.gov/timeseries/LASST270000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Mississippi
#
# link: https://data.bls.gov/timeseries/LASST280000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Missouri
#
# link: https://data.bls.gov/timeseries/LASST290000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Montana
#
# link: https://data.bls.gov/timeseries/LASST300000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Nebraska
#
# link: https://data.bls.gov/timeseries/LASST310000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Nevada
#
# link: https://data.bls.gov/timeseries/LASST320000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# New Hampshire
#
# link: https://data.bls.gov/timeseries/LASST330000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# New Jersey
#
# link: https://data.bls.gov/timeseries/LASST340000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# New Mexico
#
# link: https://data.bls.gov/timeseries/LASST350000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# New York
#
# link: https://data.bls.gov/timeseries/LASST360000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# North Carolina
#
# link: https://data.bls.gov/timeseries/LASST370000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# North Dakota
#
# link: https://data.bls.gov/timeseries/LASST380000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Ohio
#
# link: https://data.bls.gov/timeseries/LASST390000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Oklahoma
#
# link: https://data.bls.gov/timeseries/LASST400000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Oregon
#
# link: https://data.bls.gov/timeseries/LASST410000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Pennsylvania
#
# link: https://data.bls.gov/timeseries/LASST420000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Rhode Island
#
# link: https://data.bls.gov/timeseries/LASST440000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# South Carolina
#
# link: https://data.bls.gov/timeseries/LASST450000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# South Dakota
#
# link: https://data.bls.gov/timeseries/LASST460000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Tennessee
#
# link: https://data.bls.gov/timeseries/LASST470000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Texas
#
# link: https://data.bls.gov/timeseries/LASST480000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Utah
#
# link: https://data.bls.gov/timeseries/LASST490000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Vermont
#
# link: https://data.bls.gov/timeseries/LASST500000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Virginia
#
# link: https://data.bls.gov/timeseries/LASST510000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Washington
#
# link: https://data.bls.gov/timeseries/LASST530000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# West Virginia
#
# link: https://data.bls.gov/timeseries/LASST540000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Wisconsin
#
# link: https://data.bls.gov/timeseries/LASST550000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true
# Wyoming
#
# link: https://data.bls.gov/timeseries/LASST560000000000006?amp%253bdata_tool=XGtable&output_view=data&include_graphs=true

# %%
df_final
# Out:
#         State                     Key_word Jan 2010 Feb 2010 Mar 2010  \
# 0     Alabama                Total nonfarm   1881.7   1879.3   1883.1
# 1     Alabama                Total private   1493.4   1491.1   1493.4
# 2     Alabama              Goods-producing    336.4    335.2    335.9
# 3     Alabama            Service-providing   1545.3   1544.1   1547.2
# 4     Alabama    Private service-providing   1157.0   1155.9   1157.5
# ...       ...                          ...      ...      ...      ...
# 1408  Wyoming  employment-population ratio     66.6     66.7     66.8
# 1409  Wyoming                  labor force   301774   302123   302337
# 1410  Wyoming                   employment   280222   280793   281479
# 1411  Wyoming                 unemployment    21552    21330    20858
# 1412  Wyoming            unemployment rate      7.1      7.1      6.9
#
#      Apr 2010 May 2010 Jun 2010 Jul 2010 Aug 2010  ... Mar 2020 Apr 2020  \
# 0      1886.3   1898.3   1896.5   1895.7   1891.5  ...   2076.6   1865.8
# 1      1495.3   1499.1   1501.7   1503.1   1501.5  ...   1681.0   1477.1
# 2       337.0    337.5    337.7    336.8    335.8  ...    377.2    347.5
# 3      1549.3   1560.8   1558.8   1558.9   1555.7  ...   1699.4   1518.3
# 4      1158.3   1161.6   1164.0   1166.3   1165.7  ...   1303.8   1129.6
# ...       ...      ...      ...      ...      ...  ...      ...      ...
# 1408     65.2     65.3     65.4     65.5     65.6  ...     63.0     59.4
# 1409   302446   302531   302704   303001   303421  ...   295500   296644
# 1410   282195   282900   283583   284227   284841  ...   284302   268301
# 1411    20251    19631    19121    18774    18580  ...    11198    28343
# 1412      6.7      6.5      6.3      6.2      6.1  ...      3.8      9.6
#
#      May 2020   Jun 2020 Jul 2020 Aug 2020 Sep 2020 Oct 2020 Nov 2020 Dec 2020
# 0      1908.9  1954.2(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 1      1531.5  1582.5(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 2       356.1   361.6(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 3      1552.8  1592.6(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 4      1175.4  1220.9(P)      NaN      NaN      NaN      NaN      NaN      NaN
# ...       ...        ...      ...      ...      ...      ...      ...      ...
# 1408     59.5    60.6(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 1409   294481  296430(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 1410   268691  273767(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 1411    25790   22663(P)      NaN      NaN      NaN      NaN      NaN      NaN
# 1412      8.8     7.6(P)      NaN      NaN      NaN      NaN      NaN      NaN
#
# [1413 rows x 134 columns]

# %%
df_final = df_final.sort_values( by=['State'] )
df_final =df_final.reset_index(drop=True)
df_final


Filename = r'state_industry.csv' 

df_final.to_csv(Filename)
